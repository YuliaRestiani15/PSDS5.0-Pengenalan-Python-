# %% [markdown]
# **STATMENT**

# %%
print("belajar python menyenangkan")
print("halo dunia")
# Out:
# belajar python menyenangkan
# halo dunia

# %% [markdown]
# # **VARIABLES**

# %%
bilangan1=2
bilangan2=5
kalimat ="pejuang data 5"
bilangan =bilangan1+bilangan2
print("bilangan total=",bilangan)
# Out:
# bilangan total= 7

# %% [markdown]
# # **COMMENTS**

# %%
## SINGLE LINE COMMENT

#ini adalah comment
print("belajar python")
# Out:
# belajar python

# %%
##MULTI LINE COMMENT

"""
ini adalah komentar panjang
bisa digunakan untuk memberikan penjelasan
panjang pada seluruh kode python,
misal dokumentasi program,spesifikasi input output atau lainyya
"""
print('belajar python menyenangkan')
# Out:
# belajar python menyenangkan
